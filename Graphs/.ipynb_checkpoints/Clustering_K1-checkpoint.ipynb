# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_all_configurations_together(configurations):
    clusters = configurations["Energy, TrainingTime | Uniform K1"]["clusters"]

    # Set up the figure for Local Iterations
    fig, ax1 = plt.subplots(figsize=(12, 8))

    # Colors and markers for different configurations
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']

    # Plot Local Iterations as bars with space between clusters
    width = 0.3
    x = np.arange(len(clusters)) * 1.5  # Add spacing between clusters
    for i, (config_name, config_data) in enumerate(configurations.items()):
        offset = (i - len(configurations) / 2) * width
        ax1.bar(x + offset, config_data['local_iterations'], width, label=f"{config_name} - Local Iterations", alpha=0.8, color=colors[i])

    ax1.set_xlabel('Clusters', fontsize=12)
    ax1.set_ylabel('Local Iterations', fontsize=12)
    ax1.set_xticks(x)
    ax1.set_xticklabels(clusters, fontsize=10)
    ax1.legend(loc='upper left', bbox_to_anchor=(1.05, 1), fontsize=10)

    # Title and grid
    plt.title('Cluster Formations: Local Iterations', fontsize=14)
    plt.grid(axis='y', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

    # Set up the figure for Number of Clients
    fig, ax2 = plt.subplots(figsize=(12, 8))

    # Plot Number of Clients as bars with space between clusters
    for i, (config_name, config_data) in enumerate(configurations.items()):
        offset = (i - len(configurations) / 2) * width
        ax2.bar(x + offset, config_data['number_of_clients'], width, label=f"{config_name} - Number of Clients", alpha=0.8, color=colors[i])

    ax2.set_xlabel('Clusters', fontsize=12)
    ax2.set_ylabel('Number of Clients', fontsize=12)
    ax2.set_xticks(x)
    ax2.set_xticklabels(clusters, fontsize=10)
    ax2.legend(loc='upper left', bbox_to_anchor=(1.05, 1), fontsize=10)

    # Title and grid
    plt.title('Cluster Formations: Number of Clients', fontsize=14)
    plt.grid(axis='y', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

    # Set up the figure for Avg Energy
    fig, ax3 = plt.subplots(figsize=(12, 8))

    for i, (config_name, config_data) in enumerate(configurations.items()):
        energy_scaled = [e * 1e6 for e in config_data['avg_energy']]  # Scale to micro-Joules
        ax3.plot(x, energy_scaled, label=f"{config_name} - Avg Energy (μJ)", color=colors[i], linestyle='--', linewidth=1.5)

    ax3.set_xlabel('Clusters', fontsize=12)
    ax3.set_ylabel('Avg Energy (μJ)', fontsize=12)
    ax3.set_xticks(x)
    ax3.set_xticklabels(clusters, fontsize=10)
    ax3.legend(loc='upper left', bbox_to_anchor=(1.05, 1), fontsize=10)

    # Title and grid
    plt.title('Cluster Formations: Avg Energy', fontsize=14)
    plt.grid(axis='y', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

    # Set up the figure for Avg Seconds per Sample
    fig, ax4 = plt.subplots(figsize=(12, 8))

    for i, (config_name, config_data) in enumerate(configurations.items()):
        seconds_scaled = [s for s in config_data['avg_seconds_per_sample']]  # Use seconds per sample directly
        ax4.plot(x, seconds_scaled, label=f"{config_name} - Avg Seconds per Sample", color=colors[i], linestyle='-', linewidth=1.5)

    ax4.set_xlabel('Clusters', fontsize=12)
    ax4.set_ylabel('Avg Seconds per Sample', fontsize=12)
    ax4.set_xticks(x)
    ax4.set_xticklabels(clusters, fontsize=10)
    ax4.legend(loc='upper left', bbox_to_anchor=(1.05, 1), fontsize=10)

    # Title and grid
    plt.title('Cluster Formations: Avg Seconds per Sample', fontsize=14)
    plt.grid(axis='y', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# Define the configurations
configurations = {
    "Energy | Uniform K1": {
        "clusters": ["Cluster 0", "Cluster 1", "Cluster 2", "Cluster 3", "Cluster 4"],
        "avg_energy": [0.000018, 0.000011, 0.000016, 0.000013, 0.000020],
        "avg_seconds_per_sample": [0.000150, 0.000138, 0.000148, 0.000132, 0.000156],
        "local_iterations": [5, 5, 5, 5, 5],
        "number_of_clients": [11, 14, 10, 9, 6]
    },
    "Energy, TrainingTime | Uniform K1": {
        "clusters": ["Cluster 0", "Cluster 1", "Cluster 2", "Cluster 3", "Cluster 4"],
        "avg_energy": [0.000018, 0.000013, 0.000012, 0.000018, 0.000017],
        "avg_seconds_per_sample": [0.000166, 0.000173, 0.000122, 0.000137, 0.000104],
        "local_iterations": [5, 5, 5, 5, 5],
        "number_of_clients": [15, 8, 15, 7, 5]
    },
    "Energy | High K1 for Low Energy": {
        "clusters": ['Cluster 0', 'Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4'],
        "avg_energy": [0.000018, 0.000011, 0.000016, 0.000013, 0.000020],
        "avg_seconds_per_sample": [0.000150, 0.000138, 0.000148, 0.000132, 0.000156],
        "local_iterations": [4, 7, 5, 6, 3],
        "number_of_clients": [11, 14, 10, 9, 6]
    },
    "Energy | High K1 for High Energy": {
        "clusters": ['Cluster 0', 'Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4'],
        "avg_energy": [0.000018, 0.000011, 0.000016, 0.000013, 0.000020],
        "avg_seconds_per_sample": [0.000150, 0.000138, 0.000148, 0.000132, 0.000156],
        "local_iterations": [6, 3, 5, 4, 7],
        "number_of_clients": [11, 14, 10, 9, 6]
    },
    "Energy, TrainingTime | High K1 for Low Energy": {
        "clusters": ['Cluster 0', 'Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4'],
        "avg_energy": [0.000018, 0.000013, 0.000012, 0.000018, 0.000017],
        "avg_seconds_per_sample": [0.000166, 0.000173, 0.000122, 0.000137, 0.000104],
        "local_iterations": [3, 6, 7, 4, 5],
        "number_of_clients": [15, 8, 15, 7, 5]
    },
    "Energy, TrainingTime | High K1 for High Energy": {
        "clusters": ['Cluster 0', 'Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4'],
        "avg_energy": [0.000018, 0.000013, 0.000012, 0.000018, 0.000017],
        "avg_seconds_per_sample": [0.000166, 0.000173, 0.000122, 0.000137, 0.000104],
        "local_iterations": [7, 4, 3, 6, 5],
        "number_of_clients": [15, 8, 15, 7, 5],
    }
}

# Plot all configurations in separate graphs
plot_all_configurations_together(configurations)

# %% [markdown]
# ## Accuracy vs Energy Consumption for different configurations

# %%
import re
import os
import matplotlib.pyplot as plt

# List of log file paths
log_files = [
    '../Experiments/Experiment_21/Energy_TrainingTime_High_K1_for_High_Energy',
    '../Experiments/Experiment_21/Energy_TrainingTime_High_K1_for_Low_Energy',
    '../Experiments/Experiment_21/Energy_TrainingTime_Uniform K1',
    '../Experiments/Experiment_21/Energy_High_K1_for_High_Energy',
    '../Experiments/Experiment_21/Energy_High_K1_for_Low_Energy',
    '../Experiments/Experiment_21/Energy_Uniform K1'
]

# Map file paths to display-friendly labels
file_labels = {
    '../Experiments/Experiment_21/Energy_TrainingTime_High_K1_for_High_Energy': 'Energy, TrainingTime | High K1 for High Energy',
    '../Experiments/Experiment_21/Energy_TrainingTime_High_K1_for_Low_Energy': 'Energy, TrainingTime | High K1 for Low Energy',
    '../Experiments/Experiment_21/Energy_TrainingTime_Uniform K1': 'Energy, TrainingTime | Uniform K1',
    '../Experiments/Experiment_21/Energy_High_K1_for_High_Energy': 'Energy | High K1 for High Energy',
    '../Experiments/Experiment_21/Energy_High_K1_for_Low_Energy': 'Energy | High K1 for Low Energy',
    '../Experiments/Experiment_21/Energy_Uniform K1': 'Energy | Uniform K1'
}

# Extract final accuracy and energy computation from each file
accuracies = {}
energy_computations = {}

for file_path in log_files:
    with open(file_path, 'r') as file:
        content = file.read()
        # Find the last occurrence of "Accuracy:" and extract the value
        accuracy_matches = re.findall(r"Accuracy: ([0-9]+\.[0-9]+)", content)
        if accuracy_matches:
            final_accuracy = float(accuracy_matches[-1])
            accuracies[file_labels[file_path]] = final_accuracy

        # Find the last occurrence of "Energy Computation:" and extract the value
        energy_matches = re.findall(r"Energy Computation: ([0-9]+\.[0-9]+)", content)
        if energy_matches:
            final_energy = float(energy_matches[-1])
            energy_computations[file_labels[file_path]] = final_energy

# Plot the results
fig, ax1 = plt.subplots(figsize=(12, 8))

# Plot accuracy on the left y-axis
ax1.bar(accuracies.keys(), accuracies.values(), color='lightcoral', edgecolor='black', linewidth=1.2, label='Accuracy')
ax1.set_xlabel('Configurations', fontsize=14)
ax1.set_ylabel('Final Accuracy', fontsize=14, color='darkred')
ax1.tick_params(axis='y', labelcolor='darkred')
ax1.set_ylim(0.94, 1)
ax1.set_xticks(range(len(accuracies)))
ax1.set_xticklabels(accuracies.keys(), rotation=45, ha='right', fontsize=10)

# Add accuracy values on top of bars
for i, (key, value) in enumerate(accuracies.items()):
    ax1.text(i, value + 0.005, f"{value:.4f}", ha='center', fontsize=10, color='darkred')

# Plot energy computation on the right y-axis
ax2 = ax1.twinx()
ax2.plot(energy_computations.keys(), list(energy_computations.values()), color='blue', marker='o', label='Energy Computation')
ax2.set_ylabel('Final Energy Computation', fontsize=14, color='blue')
ax2.tick_params(axis='y', labelcolor='blue')

# Add energy computation values on each point
for i, (key, value) in enumerate(energy_computations.items()):
    ax2.text(i, value + 0.1, f"{value:.4f}", ha='center', fontsize=10, color='blue')

# Title and layout
plt.title('Final Accuracy and Energy Computation from Log Files', fontsize=16, fontweight='bold')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define configurations
configurations = {
    "Energy | Uniform K1": {
        "number_of_clients": [11, 14, 10, 9, 6]
    },
    "Energy, TrainingTime | Uniform K1": {
        "number_of_clients": [14, 8, 16, 7, 5]
    },
    "Energy | High K1 for Low Energy": {
        "number_of_clients": [11, 14, 10, 9, 6]
    },
    "Energy | High K1 for High Energy": {
        "number_of_clients": [11, 14, 10, 9, 6]
    },
    "Energy, TrainingTime | High K1 for Low Energy": {
        "number_of_clients": [15, 8, 15, 7, 5]
    },
    "Energy, TrainingTime | High K1 for High Energy": {
        "number_of_clients": [15, 8, 15, 7, 5]
    }
}

# Extract configuration names and number of clients
config_names = list(configurations.keys())
number_of_clients = [config["number_of_clients"] for config in configurations.values()]

# Create a bar plot
x = np.arange(len(config_names))  # the label locations
width = 0.15  # the width of the bars

fig, ax = plt.subplots(figsize=(12, 6))
for i, cluster_idx in enumerate(range(len(number_of_clients[0]))):
    cluster_values = [clients[cluster_idx] for clients in number_of_clients]
    ax.bar(x + i * width, cluster_values, width, label=f'Cluster {cluster_idx}')

# Add labels, title, and legend
ax.set_xlabel('Configurations', fontsize=12)
ax.set_ylabel('Number of Clients', fontsize=12)
ax.set_title('Number of Clients per Cluster in Each Configuration', fontsize=14)
ax.set_xticks(x + width * (len(number_of_clients[0]) - 1) / 2)
ax.set_xticklabels(config_names, rotation=45, ha="right", fontsize=10)
ax.legend(title="Clusters", fontsize=10)

plt.tight_layout()
plt.show()
